# %%
# !pip install pyngrok flask-ngrok
# !sed -i '38s/.*/    time.sleep(3)/' /usr/local/lib/python3.10/dist-packages/flask_ngrok.py
# !git clone https://github.com/marcus-wrd/serve.git
# !ngrok config upgrade
# !ngrok config add-authtoken 2WG9E9sR0XIh2lMnz6NLHhv0ybe_3e56a9tvwYDmdQEa2hEgJ
# !rsync -a --remove-source-files serve/ .
# !find serve -depth -type d -exec rmdir {} \;
# !ngrok authtoken '2WG9E9sR0XIh2lMnz6NLHhv0ybe_3e56a9tvwYDmdQEa2hEgJ'
# !apt -y update
# !apt -y remove python3-blinker
# !pip install transformers accelerate bitsandbytes torch transformers[torch] flask Flask
# !pip install scipy protobuf
from flask import Flask, render_template, request, jsonify
from flask_ngrok import run_with_ngrok
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
app = Flask(__name__)
run_with_ngrok(app)

# Load the model and tokenizer
model_name = "marcchew/Platyporoni-7B"
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", torch_dtype=torch.float16, offload_folder="/workspace")
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True, offload_folder="/workspace")

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/generate', methods=['POST'])
def generate():
    data = request.json
    prompt = data['prompt']

    # Tokenize the prompt and generate the output
    model_inputs = tokenizer(prompt, return_tensors="pt").to("cuda:0")
    output = model.generate(**model_inputs, max_length=4096)
    decoded_output = tokenizer.decode(output[0], skip_special_tokens=True, max_length=4096)

    # Extract the detailed output
    idx = decoded_output.find('Detailed Response: ') + len("Detailed Response: ")
    detailed_output = decoded_output[idx:]

    return jsonify({'output': detailed_output})

if __name__ == '__main__':
    app.run()
# Out:
# ...
# Cloning into 'serve'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 24 (delta 7), reused 18 (delta 5), pack-reused 0
# Receiving objects: 100% (24/24), 441.19 KiB | 7.23 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# No changes needed for config file: '/root/.ngrok2/ngrok.yml'
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...
